# %% [markdown]
# # Domain Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
cf = sns.load_dataset('healthexp')

# %%
cf
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
cf.tail()
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0

# %%
cf.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %%
cf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             274 non-null    int64
#  1   Country          274 non-null    object
#  2   Spending_USD     274 non-null    float64
#  3   Life_Expectancy  274 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Exploratory Data Analsysis

# %%
cf.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
#Univariate Analysis

sns.displot(data=cf.Country,kde=1)
plt.show()

# %%
sns.displot(data=cf.Life_Expectancy,kde=1)
plt.show()

# %%
sns.histplot(x=cf.Spending_USD , kde=True)
plt.show()

# %%
#Bivariate Analysis

#Analyzing Spending USD according to countries
sns.relplot(x='Country' , y='Spending_USD' , data=cf )
plt.show()
#USA spends the most Money

# %%
#Analyzing Spending USD according to the year 
sns.relplot(x='Year' , y='Spending_USD' , data=cf )
plt.show()
# Spending Money keeps on increasing as the year goes on

# %%
#Multivariate Analysis
sns.pairplot(cf)
plt.show()

# %%
# !pip install sweetviz

# %%
import sweetviz as sv

report = sv.analyze(cf)

# Show the report in browser or save it
report.show_html("sweetviz_report.html")

# %% [markdown]
# # Data Preprocessing and Feature Engineeering

# %%
cf.isnull().sum()
# Out:
# Year               0
# Country            0
# Spending_USD       0
# Life_Expectancy    0
# dtype: int64

# %%
sns.boxplot(x='Country',data=cf)
plt.show()

# %%
sns.boxplot(x='Spending_USD',data=cf)
plt.show()

# %%
sns.boxplot(x='Life_Expectancy',data=cf)
plt.show()

# %% [markdown]
# # Feature Selection

# %%
cf
# Out:
#      Year        Country  Spending_USD  Life_Expectancy
# 0    1970        Germany       252.311             70.6
# 1    1970         France       192.143             72.2
# 2    1970  Great Britain       123.993             71.9
# 3    1970          Japan       150.437             72.0
# 4    1970            USA       326.961             70.9
# ..    ...            ...           ...              ...
# 269  2020        Germany      6938.983             81.1
# 270  2020         France      5468.418             82.3
# 271  2020  Great Britain      5018.700             80.4
# 272  2020          Japan      4665.641             84.7
# 273  2020            USA     11859.179             77.0
#
# [274 rows x 4 columns]

# %%
#Checking the Corelation
sns.heatmap(cf.drop('Country',axis=1).corr(),annot=True)
plt.show()

# %% [markdown]
# # Model Creation

# %%
cf.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
#Independent and dependent variable creation
X = cf[['Year','Life_Expectancy']]
Y = cf.Spending_USD

# %%
X
# Out:
#      Year  Life_Expectancy
# 0    1970             70.6
# 1    1970             72.2
# 2    1970             71.9
# 3    1970             72.0
# 4    1970             70.9
# ..    ...              ...
# 269  2020             81.1
# 270  2020             82.3
# 271  2020             80.4
# 272  2020             84.7
# 273  2020             77.0
#
# [274 rows x 2 columns]

# %%
Y
# Out:
# 0        252.311
# 1        192.143
# 2        123.993
# 3        150.437
# 4        326.961
#          ...
# 269     6938.983
# 270     5468.418
# 271     5018.700
# 272     4665.641
# 273    11859.179
# Name: Spending_USD, Length: 274, dtype: float64

# %%
#Traning and testing data creation
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=4)

# %%
X_train
# Out:
#      Year  Life_Expectancy
# 208  2010             81.2
# 265  2019             81.4
# 142  1999             78.8
# 13   1973             71.3
# 42   1980             73.7
# ..    ...              ...
# 58   1984             76.2
# 87   1989             78.8
# 197  2008             80.2
# 174  2004             80.3
# 122  1995             79.6
#
# [219 rows x 2 columns]

# %%
Y_train
# Out:
# 208    4155.529
# 265    4385.463
# 142    2278.254
# 13      384.541
# 42     1036.300
#          ...
# 58     1135.020
# 87     1021.247
# 197    3955.136
# 174    3170.947
# 122    1413.445
# Name: Spending_USD, Length: 219, dtype: float64

# %%
len(Y_train)
# Out:
# 219

# %%
len(Y_test)
# Out:
# 55

# %%
# Creating Model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,Y_train) # training of linear regression
# Out:
# LinearRegression()

# %%
Y_predict=LR.predict(X_test)

# %%
Y_predict
# Out:
# array([5135.88159445, 3919.03403707, 6647.77507603, 1880.02497086,
#         236.42488645, 3724.06199715, 5904.98453686, -343.02633135,
#        1221.4919567 , 3371.07095116, 9023.525069  ,  483.87714619,
#        1142.41016034, 3587.03507901, 3766.19075966,  531.326224  ,
#        4730.26574199, 3450.00816087, 1516.53788091, 5599.44256868,
#        2986.44718663, -574.95140512,  684.16950141, 3007.43927456,
#        1595.61967727, 2448.98014469, 1627.25239581, 3787.32743424,
#        4240.24777786, -659.20893014, 5467.73596585,  -26.98831922,
#        3402.55908306, 3207.58704314, 3581.85935036, 1047.65659136,
#        4487.9892109 , 2496.42922251, 1874.8492422 , 2823.25245191,
#        2575.51101887, 2428.13264342, 3212.90735845, 5167.51431299,
#        2317.27354186,  894.9579006 , 2048.68460754, 5789.0942933 ,
#        3602.70685163, 5620.43465661, 6300.10434535, 3903.07309115,
#        7732.91603057,  763.25129777, 2612.31946607])

# %%
Y_test # Actual Values
# Out:
# 244     5044.275
# 248     4295.858
# 269     6938.983
# 71       578.610
# 43       898.807
# 216     4161.698
# 251     5970.163
# 46       603.965
# 45       433.957
# 192     3588.227
# 273    11859.179
# 6        298.251
# 24       591.098
# 184     3486.621
# 210     4045.065
# 18       495.114
# 246     4928.128
# 155     3009.368
# 64      1298.555
# 247     3960.141
# 154     2624.293
# 1        192.143
# 39       659.826
# 121     1094.034
# 91      1459.110
# 88      2424.654
# 100     1897.456
# 242     4515.556
# 193     3021.671
# 11       185.390
# 241     3805.820
# 33       692.269
# 139     1572.097
# 111     3286.558
# 230     4308.252
# 47      1191.537
# 266     4610.794
# 103      930.701
# 106     1930.889
# 206     2971.377
# 130     2091.997
# 188     2561.219
# 133     1507.352
# 258     5099.306
# 83      2195.392
# 69      1278.816
# 108     1753.485
# 253     4059.125
# 129     4158.928
# 213     7879.253
# 268     5828.324
# 175     2724.869
# ...

# %%
Y_predict # Predicted Values
# Out:
# array([5135.88159445, 3919.03403707, 6647.77507603, 1880.02497086,
#         236.42488645, 3724.06199715, 5904.98453686, -343.02633135,
#        1221.4919567 , 3371.07095116, 9023.525069  ,  483.87714619,
#        1142.41016034, 3587.03507901, 3766.19075966,  531.326224  ,
#        4730.26574199, 3450.00816087, 1516.53788091, 5599.44256868,
#        2986.44718663, -574.95140512,  684.16950141, 3007.43927456,
#        1595.61967727, 2448.98014469, 1627.25239581, 3787.32743424,
#        4240.24777786, -659.20893014, 5467.73596585,  -26.98831922,
#        3402.55908306, 3207.58704314, 3581.85935036, 1047.65659136,
#        4487.9892109 , 2496.42922251, 1874.8492422 , 2823.25245191,
#        2575.51101887, 2428.13264342, 3212.90735845, 5167.51431299,
#        2317.27354186,  894.9579006 , 2048.68460754, 5789.0942933 ,
#        3602.70685163, 5620.43465661, 6300.10434535, 3903.07309115,
#        7732.91603057,  763.25129777, 2612.31946607])

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2=r2_score(Y_test,Y_predict)

# %%
r2 # Model Evaluation
# Out:
# 0.8280071123653447

# %%
print(mean_absolute_error(Y_test,Y_predict))
# Out:
# 701.0243171159478

# %%
import math
print(mean_squared_error(Y_test,Y_predict))
print(math.sqrt(mean_squared_error(Y_test,Y_predict)))
# Out:
# 1021390.8385079033
# 1010.6388269346786

# %% [markdown]
# # DONE
